# %% [markdown]
# # Sequences
#
# In this chapter we look at Python's three basic sequences.

# %%
address = (2-1) * 10 + (3-1)
print("Memory location: ", address)
# Out:
# Memory location:  12

# %% [markdown]
# ## Looping Through Sequences
# We discuss the `for` loop and how it loops through sequences

# %%
for ii in [1, 2, "three"]:
   print(ii)
# Out:
# 1
# 2
# three

# %%
for cc in "Pyt":
    print(cc)
# Out:
# P
# y
# t

# %% [markdown]
# ## Ranges
# An object that produces numbers.

# %% [markdown]
# range(stop)

# %%
print(list(range(5)))
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# range(start, stop)

# %%
print(list(range(5,10)))
# Out:
# [5, 6, 7, 8, 9]

# %% [markdown]
# range(start, stop, step)

# %%
print(list(range(1,10,2)))
# Out:
# [1, 3, 5, 7, 9]

# %% [markdown]
# ## Common Sequence Operations

# %%
print("5 in list:", 5 in [1, 2, "three", 'four', 5])
print("five not in list:","five" not in [1, 2, "three", 'four', 5])
# Out:
# 5 in list: True
# five not in list: True

# %%
"cats " + "and" + " dogs"
# Out:
# 'cats and dogs'

# %%
print("(1,2) * 2 =", (1,2) * 2)
# Out:
# (1,2) * 2 = (1, 2, 1, 2)

# %%
print('"abcdef"[2] =',"abcdef"[2])
RayArray = [1,2,3,4]
print("Index 1 of [1,2,3,4] =",RayArray[1])
# Out:
# "abcdef"[2] = c
# Index 1 of [1,2,3,4] = 2

# %%
TwoDim=[[1,2,3],["a","b","c"]]
print("123\nabc at [1][1] =", TwoDim[1][1])
# Out:
# 123
# abc at [1][1] = b

# %%
letters ="abcdefghi"
print("'abcdefghi'[1:5] = ", letters[1:5])
# Out:
# 'abcdefghi'[1:5] =  bcde

# %%
first10 = list(range(1,11))
print("first10[0:9:2] = ",first10[0:9:2])
# Out:
# first10[0:9:2] =  [1, 3, 5, 7, 9]

# %%
stooges=('moe', 'larry', 'curley')
print("How many Stooges?",len(stooges))
# Out:
# How many Stooges? 3

# %%
pi_digits=['3','1','4','1','5','9']
print("min digit:", min(pi_digits))
print("max digit:", max(pi_digits))
# Out:
# min digit: 1
# max digit: 9

# %%
#      0123456789A
msg = "Mississippi"
print("first s:", msg.index('s'))
print("first s after 3",msg.index('s',3))
print("first s between 5 and 7", msg.index('s',5,8))
print("No s between 0 and 1", msg.index('s',0,2))
# Out:
# first s: 2
# first s after 3 3
# first s between 5 and 7 5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-f1f987c5beab> in <module>
#       4 print("first s after 3",msg.index('s',3))
#       5 print("first s between 5 and 7", msg.index('s',5,8))
# ----> 6 print("No s between 1 and 1", msg.index('s',0,2))
#
# ValueError: substring not found

# %%
print("s's in Mississippi:", "Mississippi".count('s'))
# Out:
# s's in Mississippi: 4
