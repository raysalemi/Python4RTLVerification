# %% [markdown]
# # The Basics
#
# Examining the built-in constants, types and operations

# %% [markdown]
# ## Constants
#
# Making an empty class

# %%
class EmptyClass:
    ...

ec = EmptyClass()
print(type(ec))
# Out:
# <class '__main__.EmptyClass'>

# %% [markdown]
# ## Number types
#
# Complex numbers!

# %%
1j*1j
# Out:
# (-1+0j)

# %% [markdown]
# ## Mutable and Immutable Objects

# %% [markdown]
# A `list` object is mutable.

# %%
ll = ['apples', 'bananas']
ll.append('jack fruit')
print(ll)
# Out:
# ['apples', 'bananas', 'jack fruit']

# %% [markdown]
# A `str` object is immutable.

# %%
cc = "Car"
cc[0] = 'B'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-eac71d94aee6> in <module>
#       1 cc = "Car"
# ----> 2 cc[0] = 'B'
#
# TypeError: 'str' object does not support item assignment
